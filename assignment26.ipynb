# %%
#LISTs
fruits = ["apple","banana","cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
x = [10,20,30,40,50]
x[1] = 25
print(x)

# %%
fruits = ["apple","banana","cherry"]
fruits.remove("banana")
print(fruits)

# %%
#TUPLE
coordinates = (4.0,5.0)
print(coordinates[0])

# %%
colours = ("red","green","blue")
print(type(len(colours)))

# %%
alphabet = ("a","b","c","d",)
alphabet = alphabet + ("e",)

# %%
mk = ('pubg')
print(type(mk))

# %%
#DICTIONARY
CAR = {
    "brand":"ford",
    "model":"mustang",
    "year":1964}
print(CAR["model"]) 
print(CAR.get("year"))
CAR["year"] = 2020          
print(CAR)

# %%
#SETs
fruits_set = {"apple","banana","cherry"}
print(fruits_set)
fruits_set.add("orange")
print(fruits_set)

# %%
set1 = {1,2.3}
set2 = {3,4,5}
un_set = set1.union(set2)
print(un_set)

# %%
x = "100"
int_x = int(x)
print(int_x)
result = int_x + 50
print(result)

# %%
y = 10.75
int_y = int(y)
print(int_y)

# %%
list = [1,2,2,3,4,4]
set_from_list = set(list)
print(set_from_list)

# %%
mkg = input("Enter a value: ")
float_mkg = float(mkg)
result = float_mkg * 2
print(result)
