# %%
stud = ["mohan", "parth", "nayan", "nayan"]
un_stud = set(stud)
print(un_stud)
un_stud = list(un_stud)
print(un_stud)
# Out:
# {'mohan', 'nayan', 'parth'}
# ['mohan', 'nayan', 'parth']

# %%
x = "250"
print(x)
print(type(x))
# Out:
# 250
# <class 'str'>

# %%
x = "99","100","101"
print(x)
print(type(x))


x_bool = bool(x_float)
print(x_bool)
print(type(x_bool))

x_list = list(x)
print(x_list)
print(type(x_list))
# Out:
# ('99', '100', '101')
# <class 'tuple'>
# True
# <class 'bool'>
# ['99', '100', '101']
# <class 'list'>

# %%
x = "45.67"
x_float = float(x)
print(x_float)
print(type(x_float))

x_int = int(x_float)
print(x_int)

y=False
print(type(y))
y
x_int = int(x_float)
print(x_int)
# Out:
# 45.67
# <class 'float'>
# 45
# <class 'bool'>
# 45

# %%
x = ("10","20","30")
x_list = list(x)
print(x_list)
print(type(x_list))
# Out:
# ['10', '20', '30']
# <class 'list'>

# %%
x = ("1","2","3","4","5")
print(type(x))
print(x[0])
print(x[4])
print(len(x))
# Out:
# <class 'tuple'>
# 1
# 5
# 5

# %%
s = "MachineLearning"
print(s[:7])
print(s[-5:])
# Out:
# Machine
# rning

# %%
m = (10,20,30,40,50)
print(m)
m.remove(50)
# Out:
# (10, 20, 30, 40, 50)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 m = (10,20,30,40,50)
#       2 print(m)
# ----> 3 m.remove(50)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
m = "PYTHON"
m_list = list(m)
print(m_list)
print(type(m_list))
# Out:
# ['P', 'Y', 'T', 'H', 'O', 'N']
# <class 'list'>

# %%
nums = [5,10,15,20]
nums.append(25)
nums.remove(10)
print(list)
# Out:
# <class 'list'>

# %%
x = "6789"
print(x)
print(type(x))
x = [int(x)]
print(x)
# Out:
# 6789
# <class 'str'>
# [6789]
