# %%
#Programs
# 1
radius = float(input("Enter a radius: "))
area = 3.14 * radius * radius
print(area)
# Out:
# 78.5

# %%
# 2
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Quotient:", a // b)
print("Remainder:", a % b)
# Out:
# Quotient: 1
# Remainder: 0

# %%
# 3
r = float(input("Enter radius: "))
volume = (4/3) * 3.14 * r**3
print(volume)
# Out:
# 33.49333333333333

# %%
# 4
balance = 1000
balance += 2000
print(balance)
# Out:
# 3000

# %%
# 5
number = 10
number **= 2
print(number)
# Out:
# 100

# %%
# 6
count = 2
count *= 10
count -= 4
count /= 2
print(count)
# Out:
# 8.0

# %%
# 7
n = int(input("Enter number: "))
print(n > 0)
# Out:
# False

# %%
# 8
mk1 = input("Enter first string: ")
mk2 = input("Enter second string: ")
print(len(mk1) == len(mk2))
# Out:
# True

# %%
# 9
age = int(input("Enter age: "))
result = age >= 65 or age <= 12
print(result)
# Out:
# True

# %%
# 10
check = int(input("Enter a number: "))
if check >= 50 and check <= 10:
    print("The number is greater than or equal to 50 and less than or equal to 10.")
else:
    print("The number is not greater than 50.")
# Out:
# The number is not greater than 50.
