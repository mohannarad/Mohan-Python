# %%
x = 46
print(x)
print(type(x))
# Out:
# 46
# <class 'int'>

# %%
students = ["mohan","parth","nayan","krishna"]
print(students)
print(type(students))
# Out:
# ['mohan', 'parth', 'nayan', 'krishna']
# <class 'list'>

# %%
x = "mohan"
print(x)
print(type(x))
# Out:
# mohan
# <class 'str'>

# %%
fruits = ["mango","banana","water melon"]
print(fruits)
print(type(fruits))
# Out:
# ['mango', 'banana', 'water melon']
# <class 'list'>

# %%
fruits = ["mango","banana","water melon"]
print(fruits)
fruits.append("Strawberry")
fruits.append("Orange")
fruits.append("Grape")
print(fruits)
fruits.remove("mango")
print(fruits)
fruits.extend(["raspberry"])
print(fruits)
fruits.pop(5)
print(fruits)
list2 = ["potato","pumpkin"]
fruits.extend(list2)
print(list2)
# Out:
# ['mango', 'banana', 'water melon']
# ['mango', 'banana', 'water melon', 'Strawberry', 'Orange', 'Grape']
# ['banana', 'water melon', 'Strawberry', 'Orange', 'Grape']
# ['banana', 'water melon', 'Strawberry', 'Orange', 'Grape', 'raspberry']
# ['banana', 'water melon', 'Strawberry', 'Orange', 'Grape']
# ['potato', 'pumpkin']
